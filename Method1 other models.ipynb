# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
data1 = pd.read_csv('dataset for method 1.csv')
X = data1[['age', 'IMD2019_decile', 'household_size', 'mor_travel', 'aft_travel',
       '#car',  'ethnicity_Pakistani','ethnicity_White British', 'gender_Female']]
Y = data1['Y1']
X_train, X_test, y_train, y_test = train_test_split(X,Y,stratify = Y)

# %%
keys = []
scores = []
models = {'K-近邻': KNeighborsClassifier(),
          '逻辑回归 l1': LogisticRegressionCV(cv=5, penalty='l1',solver='liblinear'),
          '逻辑回归 l2': LogisticRegressionCV(cv=5, penalty='l2'),
          }

for k,v in models.items():
    mod = v
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    print(str(k) + '建模效果：' + '\n')
    print(classification_report(y_test, pred))
    acc = accuracy_score(y_test, pred)
    print('分类正确率：'+ str(acc)) 
    print('\n' + '\n')
    keys.append(k)
    scores.append(acc)
    table = pd.DataFrame({'model':keys, 'accuracy score':scores})
    print(confusion_matrix(y_test, pred))

#table
# Out:
# K-近邻建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.40      0.22      0.29         9
#            0       0.83      0.96      0.89       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.80       123
#    macro avg       0.31      0.30      0.29       123
# weighted avg       0.70      0.80      0.74       123
#
# 分类正确率：0.7967479674796748
#
#
#
# [[ 2  7  0  0]
#  [ 2 96  2  0]
#  [ 0 10  0  0]
#  [ 1  3  0  0]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 逻辑回归 l1建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.81      1.00      0.90       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.81       123
#    macro avg       0.20      0.25      0.22       123
# weighted avg       0.66      0.81      0.73       123
#
# 分类正确率：0.8130081300813008
#
#
#
# [[  0   9   0   0]
#  [  0 100   0   0]
#  [  0  10   0   0]
#  [  0   4   0   0]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 逻辑回归 l2建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.81      1.00      0.90       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.81       123
#    macro avg       0.20      0.25      0.22       123
# weighted avg       0.66      0.81      0.73       123
#
# 分类正确率：0.8130081300813008
#
#
#
# [[  0   9   0   0]
#  [  0 100   0   0]
#  [  0  10   0   0]
#  [  0   4   0   0]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
table
# Out:
#      model  accuracy score
# 0     K-近邻        0.796748
# 1  逻辑回归 l1        0.813008
# 2  逻辑回归 l2        0.813008

# %%
keys = []
scores = []
models = {'决策树': DecisionTreeClassifier(),
          '高斯贝叶斯': GaussianNB(),
          '伯努利贝叶斯': BernoulliNB(),
          '多项式贝叶斯': MultinomialNB()}

for k,v in models.items():
    mod = v
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    print(str(k) + '建模效果：' + '\n')
    print(classification_report(y_test, pred))
    acc = accuracy_score(y_test, pred)
    print('分类正确率：'+ str(acc)) 
    print('\n' + '\n')
    keys.append(k)
    scores.append(acc)
    table = pd.DataFrame({'model':keys, 'accuracy score':scores})
    print(confusion_matrix(y_test, pred))
# Out:
# 决策树建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.79      0.81      0.80       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.66       123
#    macro avg       0.20      0.20      0.20       123
# weighted avg       0.65      0.66      0.65       123
#
# 分类正确率：0.6585365853658537
#
#
#
# [[ 0  9  0  0]
#  [ 5 81 11  3]
#  [ 1  9  0  0]
#  [ 1  3  0  0]]
# 高斯贝叶斯建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.81      0.99      0.89       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.80       123
#    macro avg       0.20      0.25      0.22       123
# weighted avg       0.66      0.80      0.73       123
#
# 分类正确率：0.8048780487804879
#
#
#
# [[ 0  9  0  0]
#  [ 1 99  0  0]
#  [ 0 10  0  0]
#  [ 0  4  0  0]]
# 伯努利贝叶斯建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.81      1.00      0.90       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.81       123
#    macro avg       0.20      0.25      0.22       123
# weighted avg       0.66      0.81      0.73       123
#
# 分类正确率：0.8130081300813008
#
#
#
# [[  0   9   0   0]
#  [  0 100   0   0]
#  [  0  10   0   0]
#  [  0   4   0   0]]
# 多项式贝叶斯建模效果：
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         9
#            0       0.81      1.00      0.90       100
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.81       123
#    macro avg       0.20      0.25      0.22       123
# weighted avg       0.66      0.81      0.73       123
#
# 分类正确率：0.8130081300813008
#
#
#
# [[  0   9   0   0]
#  [  0 100   0   0]
#  [  0  10   0   0]
#  [  0   4   0   0]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
corr_aug = X.corr()
ax = sns.heatmap(
    corr_aug, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
from feature_selector import FeatureSelector

# %%
data=pd.read_csv('processed.csv')
data.shape
# Out:
# (633, 28)

# %%
fs = FeatureSelector(data.drop(['Y1','Y2'],axis=1), labels = data['Y1'])

# %%
fs.identify_missing(missing_threshold=0.2)
fs.plot_missing()
# Out:
# 1 features with greater than 0.20 missing values.

# %%
fs.missing_stats.head()
# Out:
#                 missing_fraction
# unwill_walk             0.402844
# household_size          0.085308
# #car                    0.072670
# aft_travel              0.022117
# mor_travel              0.014218

# %%
fs.identify_single_unique()
# Out:
# 0 features with a single unique value.

# %%
fs.plot_unique()

# %%
fs.unique_stats
# Out:
#                          nunique
# mode_now_Bicycle               2
# mode_before_Taxi               2
# mode_before_School Bus         2
# mode_before_Other bus          2
# mode_before_Car/Van            2
# mode_before_Bicycle            2
# mode_now_Walk                  2
# mode_now_Train                 2
# mode_now_Taxi                  2
# mode_now_School Bus            2
# mode_now_Other bus             2
# mode_now_Car/Van               2
# mode_before_Walk               2
# gender_Male                    2
# gender_Female                  2
# ethnicity_White British        2
# ethnicity_Pakistani            2
# ethnicity_Other                2
# mode_before_Train              2
# unwill_walk                    4
# #car                           4
# age                            4
# aft_travel                     5
# mor_travel                     5
# IMD2019_decile                10
# household_size                11

# %%
fs.identify_collinear(correlation_threshold=0.05)
# Out:
# 7 features with a correlation magnitude greater than 0.05.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:5]
# Out:
# ['household_size', 'mor_travel', 'aft_travel', '#car', 'ethnicity_Pakistani']

# %%
fs.plot_collinear(plot_all=True)

# %%
fs.record_collinear
# Out:
#                drop_feature         corr_feature  corr_value
# 0            household_size       IMD2019_decile   -0.209132
# 1                mor_travel                  age   -0.075946
# 2                mor_travel       IMD2019_decile    0.059200
# 3                mor_travel       household_size   -0.082205
# 4                aft_travel                  age   -0.086766
# 5                aft_travel       IMD2019_decile    0.051673
# 6                aft_travel       household_size   -0.088120
# 7                aft_travel           mor_travel    0.756088
# 8                      #car                  age    0.126003
# 9                      #car       IMD2019_decile    0.177633
# 10                     #car       household_size    0.101435
# 11                     #car           mor_travel   -0.288510
# 12                     #car           aft_travel   -0.262042
# 13      ethnicity_Pakistani                  age    0.081140
# 14      ethnicity_Pakistani       IMD2019_decile   -0.372094
# 15      ethnicity_Pakistani       household_size    0.396832
# 16      ethnicity_Pakistani           mor_travel   -0.210292
# 17      ethnicity_Pakistani           aft_travel   -0.208724
# 18      ethnicity_Pakistani                 #car    0.065852
# 19  ethnicity_White British       IMD2019_decile    0.457304
# 20  ethnicity_White British       household_size   -0.312785
# 21  ethnicity_White British           mor_travel    0.224171
# 22  ethnicity_White British           aft_travel    0.202000
# 23  ethnicity_White British  ethnicity_Pakistani   -0.701265
# 24            gender_Female       IMD2019_decile   -0.077939
# 25            gender_Female       household_size    0.087134
# 26            gender_Female                 #car   -0.050648
# 27            gender_Female  ethnicity_Pakistani    0.060611

# %%
X
# Out:
#      age  IMD2019_decile  household_size  mor_travel  aft_travel  #car  \
# 0     12               1               5           1           1     3
# 1     12               4               4           3           3     3
# 2     12               1               3           2           3     3
# 3     12               8               4           5           4     3
# 4     10               8               4           1           2     3
# ..   ...             ...             ...         ...         ...   ...
# 484   11               1               3           5           4     2
# 485   11               4               3           3           3     2
# 486   11               8               4           5           5     2
# 487    9               8               4           5           5     2
# 488    9               7               3           1           1     3
#
#      ethnicity_Pakistani  ethnicity_White British  gender_Female
# 0                      0                        1              1
# 1                      0                        1              1
# 2                      0                        1              1
# 3                      0                        1              0
# 4                      0                        1              0
# ..                   ...                      ...            ...
# 484                    0                        0              0
# 485                    0                        0              1
# 486                    0                        1              0
# 487                    0                        1              0
# 488                    0                        1              1
#
# [489 rows x 9 columns]

# %%
fs = FeatureSelector(X, labels = Y)

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-57-47b00f66835b> in <module>
#       1 fs.identify_zero_importance(task = 'classification', eval_metric = 'auc',
# ----> 2                             n_iterations = 10, early_stopping = True)
#
# ~\Desktop\project\data\feature_selector.py in identify_zero_importance(self, task, eval_metric, n_iterations, early_stopping)
#     309                 model.fit(train_features, train_labels, eval_metric = eval_metric,
#     310                           eval_set = [(valid_features, valid_labels)],
# --> 311                           early_stopping_rounds = 100, verbose = -1)
#     312
#     313                 # Clean up memory
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     855                                         verbose=verbose, feature_name=feature_name,
#     856                                         categorical_feature=categorical_feature,
# --> 857                                         callbacks=callbacks, init_model=init_model)
#     858         return self
#     859
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     615                               evals_result=evals_result, fobj=self._fobj, feval=eval_metrics_callable,
#     616                               verbose_eval=verbose, feature_name=feature_name,
# --> 617                               callbacks=callbacks, init_model=init_model)
#     618
#     619         if evals_result:
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     229     # construct booster
#     230     try:
# --> 231         booster = Booster(params=params, train_set=train_set)
#     232         if is_valid_contain_train:
#     233             booster.set_train_data_name(train_data_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2051                     break
#    2052             # construct booster object
# -> 2053             train_set.construct()
#    2054             # copy the parameters from train_set
#    2055             params.update(train_set.get_params())
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#    1323                                 init_score=self.init_score, predictor=self._predictor,
#    1324                                 silent=self.silent, feature_name=self.feature_name,
# -> 1325                                 categorical_feature=self.categorical_feature, params=self.params)
#    1326             if self.free_raw_data:
#    1327                 self.data = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1121             self.__init_from_csc(data, params_str, ref_dataset)
#    1122         elif isinstance(data, np.ndarray):
# -> 1123             self.__init_from_np2d(data, params_str, ref_dataset)
#    1124         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#    1125             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#    1171             c_str(params_str),
#    1172             ref_dataset,
# -> 1173             ctypes.byref(self.handle)))
#    1174         return self
#    1175
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _safe_call(ret)
#      53     """
#      54     if ret != 0:
# ---> 55         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      56
#      57
#
# LightGBMError: Multiclass objective and metrics don't match

# %%
# Out:
#      age  IMD2019_decile  household_size  mor_travel  aft_travel  #car  \
# 0     12               1             5.0         1.0         1.0   3.0
# 2     12               4             4.0         3.0         3.0   3.0
# 3     12               1             3.0         2.0         3.0   3.0
# 4     12               8             4.0         5.0         4.0   3.0
# 5     10               8             4.0         1.0         2.0   3.0
# ..   ...             ...             ...         ...         ...   ...
# 627   11               1             3.0         5.0         4.0   2.0
# 628   11               4             3.0         3.0         3.0   2.0
# 630   11               8             4.0         5.0         5.0   2.0
# 631    9               8             4.0         5.0         5.0   2.0
# 632    9               7             3.0         1.0         1.0   3.0
#
#      ethnicity_Other  ethnicity_Pakistani  ethnicity_White British  \
# 0                  0                    0                        1
# 2                  0                    0                        1
# 3                  0                    0                        1
# 4                  0                    0                        1
# 5                  0                    0                        1
# ..               ...                  ...                      ...
# 627                0                    0                        0
# 628                0                    0                        0
# 630                0                    0                        1
# 631                0                    0                        1
# 632                0                    0                        1
#
#      gender_Female  ...  mode_now_Taxi  mode_now_Train  mode_now_Walk  \
# 0                1  ...              0               0              0
# 2                1  ...              0               0              1
# 3                1  ...              0               0              1
# 4                0  ...              0               0              1
# 5                0  ...              0               0              1
# ..             ...  ...            ...             ...            ...
# 627              0  ...              0               0              1
# 628              1  ...              0               0              0
# 630              0  ...              0               0              1
# 631              0  ...              0               0              1
# 632              1  ...              0               0              0
#
#      mode_before_Bicycle  mode_before_Car/Van  mode_before_Other bus  \
# 0                      0                    1                      0
# 2                      0                    0                      0
# 3                      0                    1                      0
# 4                      0                    0                      0
# 5                      0                    1                      0
# ..                   ...                  ...                    ...
# 627                    0                    0                      0
# 628                    0                    1                      0
# 630                    0                    0                      0
# 631                    0                    1                      0
# 632                    0                    1                      0
#
#      mode_before_School Bus  mode_before_Taxi  mode_before_Train  \
# 0                         0                 0                  0
# 2                         0                 0                  0
# 3                         0                 0                  0
# 4                         0                 0                  0
# 5                         0                 0                  0
# ..                      ...               ...                ...
# 627                       0                 0                  0
# 628                       0                 0                  0
# 630                       0                 0                  0
# 631                       0                 0                  0
# 632                       0                 0                  0
#
#      mode_before_Walk
# 0                   0
# 2                   1
# 3                   0
# 4                   1
# 5                   0
# ..                ...
# 627                 1
# 628                 0
# 630                 1
# 631                 0
# 632                 0
#
# [491 rows x 25 columns]

# %%
# Out:
# 0      0.0
# 2      0.0
# 3      1.0
# 4      0.0
# 5      1.0
#       ...
# 627    0.0
# 628    2.0
# 630    0.0
# 631    1.0
# 632    0.0
# Name: Y1, Length: 491, dtype: float64
